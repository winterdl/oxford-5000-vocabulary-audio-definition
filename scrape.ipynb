# %% [markdown]
# # Scrape oxford 3000,5000 words from website
# https://www.oxfordlearnersdictionaries.com/wordlists/oxford3000-5000"
#
# Using selenium, beautifulsoup, pandas
#
# https://www.oxfordlearnersdictionaries.com/us/legal-notice
#
# intellectual property rights
#
# https://github.com/mozilla/geckodriver/releases
# ```
# $ tar -xf geckodriver-v0.30.0-linux64.tar.gz
# $ chmod +x geckodriver
# $ cp geckodriver /usr/local/bin
# ```

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
driver = webdriver.Firefox()
driver.get("https://www.oxfordlearnersdictionaries.com/wordlists/oxford3000-5000")

# %%
# Make sure oxford 5000 is selected
content = driver.page_source
soup = BeautifulSoup(content)
wordlistsContentPanel = soup.find("div", {"id": "wordlistsContentPanel"})
wordlist = wordlistsContentPanel.find("ul")

# %% [markdown]
# ## Each word in wordlist looks like
# ```
# <li data-hw="a" data-ox3000="a1" data-ox5000="a1">
#  <a href="/definition/english/a_1">
#   a
#  </a>
#  <span class="pos">
#   indefinite article
#  </span>
#  <div>
#   <span class="belong-to">
#    a1
#   </span>
#   <div class="sound audio_play_button icon-audio pron-uk" data-src-mp3="/media/english/uk_pron/a/a__/a__gb/a__gb_2.mp3" data-src-ogg="/media/english/uk_pron_ogg/a/a__/a__gb/a__gb_2.ogg">
#   </div>
#   <div class="sound audio_play_button icon-audio pron-us" data-src-mp3="/media/english/us_pron/a/a__/a__us/a__us_2_rr.mp3" data-src-ogg="/media/english/us_pron_ogg/a/a__/a__us/a__us_2_rr.ogg">
#   </div>
#  </div>
# </li>
# ```

# %%
# Create empty a frame with columns we wish to extract
columns = ["word", "definition_link", "type", "cefr", "UK", "US"]
df = pd.DataFrame(columns=columns)

# Extract fields from wordlist
words = wordlist.findChildren("li", recursive=False)
for word in words:
    if word.has_attr("class"):
        # Skip where class="hidden"
        continue
    a = word.find("a")
    word_name = a.text
    definition_link = a["href"]
    type = word.find("span").text
    div = word.find("div")
    cefr = div.find("span").text
    try:
        uk = div.find("div", {"class": "sound audio_play_button icon-audio pron-uk"})["data-src-mp3"]
        us = div.find("div", {"class": "sound audio_play_button icon-audio pron-us"})["data-src-mp3"]
    except TypeError:
        uk = ""
        us = ""
    # Add data to dataframe
    data = {
        "word": word_name,
        "definition_link": definition_link,
        "type": type,
        "cefr": cefr,
        "UK": uk,
        "US": us,
    }
    df_new = pd.DataFrame.from_records([data])
    df = pd.concat([df, df_new])

# %%
# Save data to pkl file
#df.to_pickle("./data/df.pkl")
df = pd.read_pickle("./data/df.pkl")

# %% [markdown]
# ## Scrape audio with requests
# requests to grab audio and save to `./audio` directory
#
# formatted as `{word}_uk.mp3`
#
# Example:
# * word: A
# * relative URL: `/media/english/us_pron/a/a__/a__us/a__us_2_rr.mp3`
# * full URL: `https://www.oxfordlearnersdictionaries.com/media/english/us_pron/a/a__/a__us/a__us_2_rr.mp3`
#
# ```
# Host: www.oxfordlearnersdictionaries.com
# User-Agent: xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Accept: audio/webm,audio/ogg,audio/wav,audio/*;q=0.9,application/ogg;q=0.7,video/*;q=0.6,*/*;q=0.5
# Accept-Language: en-US,en;q=0.5
# Referer: https://www.oxfordlearnersdictionaries.com/wordlists/oxford3000-5000
# Range: bytes=0-
# Connection: keep-alive
# Cookie: xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Sec-Fetch-Dest: audio
# Sec-Fetch-Mode: no-cors
# Sec-Fetch-Site: same-origin
# If-Modified-Since: xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# If-None-Match: ""
# ```

# %%
import requests
from pathlib import Path
from time import sleep
import string

# %%
# select which data to grab or continue if time-out or connectionrefused etc
# MUST_START_WITH = ['a']
# MUST_START_WITH = [x for x in string.ascii_lowercase if x != 'a']
MUST_START_WITH = [x for x in string.ascii_lowercase]
CONTINUE_AFTER_WORD, AFTER_WORD = False, "visual"
TIME_BETWEEN_REQUESTS = 0 # time to wait between requests (in seconds)

AUDIO_PATH = Path("./audio")
BASE_URL = 'https://www.oxfordlearnersdictionaries.com'

callback = 'angular.callbacks._0'
headers = {
    'Referer': 'https://www.oxfordlearnersdictionaries.com/wordlists/oxford3000-5000',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/75.0.3770.100 Safari/537.36',
}
params = (
    ('callback', callback),
)

with requests.Session() as session:
    for _, row in df.iterrows():
        # Continue after word
        if CONTINUE_AFTER_WORD:
            if row.word == AFTER_WORD:
                CONTINUE_AFTER_WORD = False
            continue

        # Select data to request
        if row.word[0].lower() not in MUST_START_WITH:
            continue

        # Skip if no audio urls
        if row.US == "" or row.UK == "":
            continue

        # Request and Write UK audio file
        filename = Path(f"{row.word}_uk.mp3")
        url = BASE_URL + row.UK

        response = session.get(url, headers=headers, params=params)
        assert response.headers["Content-Type"] == "audio/mpeg"
        with open(AUDIO_PATH / filename, "wb") as file:
            file.write(response.content)

        sleep(TIME_BETWEEN_REQUESTS)

        # Request and Write US audio file
        filename = Path(f"{row.word}_us.mp3")
        url = BASE_URL + row.US

        response = session.get(url, headers=headers, params=params)
        assert response.headers["Content-Type"] == "audio/mpeg"
        with open(AUDIO_PATH / filename, "wb") as file:
            file.write(response.content)

        sleep(TIME_BETWEEN_REQUESTS)

# %% [markdown]
# ## Dictionary definition
# Request
# * word: A
# * Relative URL: `/definition/english/a_1`
# * Full URL: `https://www.oxfordlearnersdictionaries.com/definition/english/a_1`

# %%
from selenium.webdriver.firefox.options import Options

options = Options()
options.headless = True
driver = webdriver.Firefox(options=options)

columns = ["word", "phon_br", "phon_n_am", "definition", "example"]
df_definition = pd.DataFrame(columns=columns)

# %%
# This cell runs slowly and tends to crash multiple times
# Use the CONTINUE_AFTER_WORD option
# select which data to grab or continue if time-out or connectionrefused etc
# MUST_START_WITH = ['a']
# MUST_START_WITH = [x for x in string.ascii_lowercase if x != 'a']
MUST_START_WITH = [x for x in string.ascii_lowercase]
CONTINUE_AFTER_WORD, AFTER_WORD, OFFSET = True, "register", 1
BASE_URL = 'https://www.oxfordlearnersdictionaries.com'

offset = 0
for idx, row in df.iterrows():
    # Continue after word
    if CONTINUE_AFTER_WORD:
        if row.word == AFTER_WORD:
            if offset == OFFSET:
                CONTINUE_AFTER_WORD = False
            else:
                offset += 1
        continue

    # Select data to request
    if row.word[0].lower() not in MUST_START_WITH:
        continue

    # Request definition
    url = BASE_URL + row.definition_link
    driver.get(url)

    # Extract fields
    content = driver.page_source
    soup = BeautifulSoup(content)

    main_container = soup.find("div", {"id": "main-container"})
    try:
        phonetics = soup.find("span", {"class": "phonetics"})
        phon_br = phonetics.find("div", {"class":"phons_br"}).find("span", {"class": "phon"}).text
        phon_n_am = phonetics.find("div", {"class":"phons_n_am"}).find("span", {"class": "phon"}).text
    except AttributeError:
        print("phonetics", row.word, page_id)
        phon_br = ""
        phon_n_am = ""

    page_id = row.definition_link.split('/')[-1]
    try:
        entry = main_container.find("div", {"id": page_id})
    except AttributeError:
        pass
    try:
        definition = entry.find("ol").find("li").find("span", {"class": "def"}).text
        examples = entry.find("ol").find("ul", {"class": "examples"}).find("li")
        first_example = ', '.join([x.text for x in examples.findChildren("span", recursive=False)])
        example = first_example.replace("<span>", "").replace("</span>", "")
    except AttributeError:
        print("definition", row.word, page_id)
        definition = ""
        example = ""

    # Add data
    data = {
        "word": row.word,
        "phon_br": phon_br,
        "phon_n_am": phon_n_am,
        "definition": definition,
        "example": example,
    }
    df_new = pd.DataFrame.from_records([data])
    df_definition = pd.concat([df_definition, df_new])
# Out:
# definition rely rely
# definition row row1_1#row1_sng_1
# definition sake sake1
# definition seventeen seventeen
# definition seventy seventy
# definition sixteen sixteen
# definition sixty sixty
# definition sum sum_2
# definition text text_2#text_sng_9
# definition thirteen thirteen
# definition thirty thirty
# definition this this_1#this_sng_1
# definition trillion trillion
# definition twenty twenty
# definition upon upon
# definition wind wind1_1#wind1_sng_1
# definition yeah yeah
# phonetics yield yield_1

# %%
df_definition.tail()
# Out:
#           word     phon_br    phon_n_am  \
# 5938     yours      /jɔːz/       /jərz/
# 5939  yourself  /jɔːˈself/  /jɔːrˈself/
# 5940     youth      /juːθ/       /juːθ/
# 5941      zero   /ˈzɪərəʊ/     /ˈzɪrəʊ/
# 5942      zone      /zəʊn/       /zəʊn/
#
#                                              definition  \
# 5938                             of or belonging to you
# 5939  used when the person or people being spoken to...
# 5940  the time of life when a person is young, espec...
# 5941                                                  0
# 5942  an area or a region with a particular feature ...
#
#                                                 example
# 5938                                Is that book yours?
# 5939                            Have you hurt yourself?
# 5940  in somebody's youth, He had been a talented mu...
# 5941  Five, four, three, two, one, zero… We have lif...
# 5942          a war/combat/demilitarized/exclusion zone

# %%
# Save data to pkl file
#df_definition.to_pickle("./data/df_definition.pkl")
df_definition = pd.read_pickle("./data/df_definition.pkl")

# %% [markdown]
# ## Fix and merge df and df_definition

# %%
df = df.reset_index()
del df['index']

# %%
df.head()
# Out:
#       word                definition_link                type cefr  \
# 0        a        /definition/english/a_1  indefinite article   a1
# 1  abandon  /definition/english/abandon_1                verb   b2
# 2  ability  /definition/english/ability_1                noun   a2
# 3     able     /definition/english/able_1           adjective   a2
# 4  abolish    /definition/english/abolish                verb   c1
#
#                                                   UK  \
# 0     /media/english/uk_pron/a/a__/a__gb/a__gb_2.mp3
# 1  /media/english/uk_pron/a/aba/aband/abandon__gb...
# 2  /media/english/uk_pron/a/abi/abili/ability__gb...
# 3  /media/english/uk_pron/a/abl/able_/able__gb_1.mp3
# 4  /media/english/uk_pron/a/abo/aboli/abolish__gb...
#
#                                                   US
# 0  /media/english/us_pron/a/a__/a__us/a__us_2_rr.mp3
# 1  /media/english/us_pron/a/aba/aband/abandon__us...
# 2  /media/english/us_pron/a/abi/abili/ability__us...
# 3  /media/english/us_pron/a/abl/able_/able__us_2.mp3
# 4  /media/english/us_pron/a/abo/aboli/abolish__us...

# %%
print(df.shape)
print(df_definition.shape)
# Out:
# (5943, 6)
# (5943, 5)

# %%
# Sort
# df_definition.sort_values(by=['word'], key=lambda col: col.str.lower()).head()

# Reset index
df_definition = df_definition.reset_index()
del df_definition['index']

# %%
print(df.shape)
print(df_definition.shape)
assert(df.shape[0] == df_definition.shape[0])
# Out:
# (5943, 6)
# (5943, 5)

# %%
df_concat = pd.concat([df, df_definition], axis=1)

# %%
df_concat.shape
# Out:
# (5943, 11)

# %% [markdown]
# ## Add missing dictionary entries
# input manually or use other dictionary

# %%
df_concat[df_concat["definition"] == ""]
# Out:
#                 word                                   definition_link  \
# 219           amount                      /definition/english/amount_2
# 1093         consist                       /definition/english/consist
# 1104  constitutional              /definition/english/constitutional_2
# 1137        contrary   /definition/english/contrary1_1#contrary1_sng_1
# 1428         deprive                       /definition/english/deprive
# 1431          derive                        /definition/english/derive
# 1473          devote                        /definition/english/devote
# 1717           eight             /definition/english/eight#eight_sng_1
# 1718        eighteen                      /definition/english/eighteen
# 1719          eighty                        /definition/english/eighty
# 2086      film-maker                    /definition/english/film-maker
# 2203           forty                         /definition/english/forty
# 2212            four               /definition/english/four#four_sng_1
# 2213        fourteen                      /definition/english/fourteen
# 2332   globalization                 /definition/english/globalization
# 2383      greenhouse                    /definition/english/greenhouse
# 2600        hydrogen                      /definition/english/hydrogen
# 2717  infrastructure                /definition/english/infrastructure
# 2976            lead       /definition/english/lead1_2#lead_hm1_sng_21
# 3214         martial                       /definition/english/martial
# 3499        nineteen                      /definition/english/nineteen
# 3739             pan             /definition/english/pan1_1#pan1_sng_1
# 3811         pension     /definition/english/pension1_1#pension1_sng_1
# 4081         process  /definition/english/process1_2#process_hm1_sng_4
# 4365            rely                          /definition/english/rely
# 4536             row             /definition/english/row1_1#row1_sng_1
# 4570            sake                         /definition/english/sake1
# 4699       seventeen                     /definition/english/seventeen
# 4700         seventy                       /definition/english/seventy
# 4816         sixteen                       /definition/english/sixteen
# 4817           sixty                         /definition/english/sixty
# 5152             sum                         /definition/english/sum_2
# 5315            text             /definition/english/text_2#text_sng_9
# 5358        thirteen                      /definition/english/thirteen
# 5359          thirty                        /definition/english/thirty
# 5362            this             /definition/english/this_1#this_sng_1
# 5519        trillion                      /definition/english/trillion
# 5552          twenty                        /definition/english/twenty
# 5625            upon                          /definition/english/upon
# 5851            wind           /definition/english/wind1_1#wind1_sng_1
# 5921            yeah                          /definition/english/yeah
#
#              type cefr                                                 UK  \
# 219          verb   b2  /media/english/uk_pron/a/amo/amoun/amount__gb_...
# 1093         verb   b1  /media/english/uk_pron/x/xco/xcons/xconsist__g...
# 1104    adjective   c1  /media/english/uk_pron/x/xco/xcons/xconstituti...
# 1137    adjective   c1  /media/english/uk_pron/x/xco/xcont/xcontrary__...
# 1428         verb   c1  /media/english/uk_pron/d/dep/depri/deprive__gb...
# 1431         verb   b2  /media/english/uk_pron/d/der/deriv/derive__gb_...
# 1473         verb   b2  /media/english/uk_pron/d/dev/devot/devote__gb_...
# 1717       number   a1  /media/english/uk_pron/e/eig/eight/eight__gb_2...
# 1718       number   a1  /media/english/uk_pron/e/eig/eight/eighteen__g...
# 1719       number   a1  /media/english/uk_pron/e/eig/eight/eighty__gb_...
# 2086         noun   c1  /media/english/uk_pron/f/fil/film_/film_maker_...
# 2203       number   a1  /media/english/uk_pron/f/for/forty/forty__gb_2...
# 2212       number   a1  /media/english/uk_pron/f/fou/four_/four__gb_2.mp3
# 2213       number   a1  /media/english/uk_pron/f/fou/fourt/fourteen__g...
# 2332         noun   b2  /media/english/uk_pron/g/glo/globa/globalizati...
# 2383         noun   b2  /media/english/uk_pron/g/gre/green/greenhouse_...
# 2600         noun   c1  /media/english/uk_pron/h/hyd/hydro/hydrogen__g...
# 2717         noun   b2  /media/english/uk_pron/i/inf/infra/infrastruct...
# 2976         noun   b1  /media/english/uk_pron/l/lea/lead_/lead__gb_1.mp3
# 3214    adjective   b2  /media/english/uk_pron/m/mar/marti/martial__gb...
# 3499       number   a1  /media/english/uk_pron/n/nin/ninet/nineteen__g...
# 3739         noun   b1   /media/english/uk_pron/p/pan/pan__/pan__gb_2.mp3
# 3811         noun   b2  /media/english/uk_pron/p/pen/pensi/pension__gb...
# 4081         verb   b2  /media/english/uk_pron/p/pro/proce/process__gb...
# 4365         verb   b2  /media/english/uk_pron/r/rel/rely_/rely__gb_1.mp3
# 4536         noun   b1   /media/english/uk_pron/r/row/row__/row__gb_1.mp3
# 4570         noun   c1  /media/english/uk_pron/s/sak/sake_/sake__gb_1.mp3
# 4699       number   a1  /media/english/uk_pron/s/sev/seven/seventeen__...
# 4700       number   a1  /media/english/uk_pron/s/sev/seven/seventy__gb...
# 4816       number   a1  /media/english/uk_pron/s/six/sixte/sixteen__gb...
# 4817       number   a1  /media/english/uk_pron/s/six/sixty/sixty__gb_2...
# 5152         verb   b2   /media/english/uk_pron/s/sum/sum__/sum__gb_1.mp3
# 5315         verb   a2  /media/english/uk_pron/t/tex/text_/text__gb_1.mp3
# 5358       number   a1  /media/english/uk_pron/t/thi/thirt/thirteen__g...
# 5359       number   a1  /media/english/uk_pron/t/thi/thirt/thirty__gb_...
# 5362      pronoun   a1  /media/english/uk_pron/t/thi/this_/this__gb_1.mp3
# 5519       number   b2  /media/english/uk_pron/t/tri/trill/trillion__g...
# 5552       number   a1  /media/english/uk_pron/t/twe/twent/twenty__gb_...
# 5625  preposition   b1  /media/english/uk_pron/u/upo/upon_/upon__gb_1.mp3
# 5851         noun   a2  /media/english/uk_pron/w/win/wind_/wind__gb_1.mp3
# 5921  exclamation   a1  /media/english/uk_pron/y/yea/yeah_/yeah__gb_1.mp3
#
#                                                      US            word  \
# 219   /media/english/us_pron/a/amo/amoun/amount__us_...          amount
# 1093  /media/english/us_pron/x/xco/xcons/xconsist__u...         consist
# 1104  /media/english/us_pron/x/xco/xcons/xconstituti...  constitutional
# 1137  /media/english/us_pron/x/xco/xcont/xcontrary__...        contrary
# 1428  /media/english/us_pron/d/dep/depri/deprive__us...         deprive
# 1431  /media/english/us_pron/d/der/deriv/derive__us_...          derive
# 1473  /media/english/us_pron/d/dev/devot/devote__us_...          devote
# 1717  /media/english/us_pron/e/eig/eight/eight__us_1...           eight
# 1718  /media/english/us_pron/e/eig/eight/eighteen__u...        eighteen
# 1719  /media/english/us_pron/e/eig/eight/eighty__us_...          eighty
# 2086  /media/english/us_pron/f/fil/film_/film_maker_...      film-maker
# 2203  /media/english/us_pron/f/for/forty/forty__us_1...           forty
# 2212  /media/english/us_pron/f/fou/four_/four__us_1.mp3            four
# 2213  /media/english/us_pron/f/fou/fourt/fourteen__u...        fourteen
# 2332  /media/english/us_pron/g/glo/globa/globalizati...   globalization
# 2383  /media/english/us_pron/g/gre/green/greenhouse_...      greenhouse
# 2600  /media/english/us_pron/h/hyd/hydro/hydrogen__u...        hydrogen
# 2717  /media/english/us_pron/i/inf/infra/infrastruct...  infrastructure
# 2976  /media/english/us_pron/l/lea/lead_/lead__us_1.mp3            lead
# 3214  /media/english/us_pron/m/mar/marti/martial__us...         martial
# 3499  /media/english/us_pron/n/nin/ninet/nineteen__u...        nineteen
# 3739   /media/english/us_pron/p/pan/pan__/pan__us_1.mp3             pan
# 3811  /media/english/us_pron/p/pen/pensi/pension__us...         pension
# 4081  /media/english/us_pron/p/pro/proce/process__us...         process
# 4365  /media/english/us_pron/r/rel/rely_/rely__us_1.mp3            rely
# 4536   /media/english/us_pron/r/row/row__/row__us_1.mp3             row
# 4570  /media/english/us_pron/s/sak/sake_/sake__us_1.mp3            sake
# 4699  /media/english/us_pron/s/sev/seven/seventeen__...       seventeen
# 4700  /media/english/us_pron/s/sev/seven/seventy__us...         seventy
# 4816  /media/english/us_pron/s/six/sixte/sixteen__us...         sixteen
# 4817  /media/english/us_pron/s/six/sixty/sixty__us_1...           sixty
# 5152   /media/english/us_pron/s/sum/sum__/sum__us_1.mp3             sum
# 5315  /media/english/us_pron/t/tex/text_/text__us_1.mp3            text
# 5358  /media/english/us_pron/t/thi/thirt/thirteen__u...        thirteen
# 5359  /media/english/us_pron/t/thi/thirt/thirty__us_...          thirty
# 5362  /media/english/us_pron/t/thi/this_/this__us_1.mp3            this
# 5519  /media/english/us_pron/t/tri/trill/trillion__u...        trillion
# 5552  /media/english/us_pron/t/twe/twent/twenty__us_...          twenty
# 5625  /media/english/us_pron/u/upo/upon_/upon__us_1_...            upon
# 5851  /media/english/us_pron/w/win/wind_/wind__us_1.mp3            wind
# 5921  /media/english/us_pron/y/yea/yeah_/yeah__us_1.mp3            yeah
#
#                   phon_br           phon_n_am definition example
# 219             /əˈmaʊnt/           /əˈmaʊnt/
# 1093           /kənˈsɪst/          /kənˈsɪst/
# 1104   /ˌkɒnstɪˈtjuːʃənl/  /ˌkɑːnstɪˈtuːʃənl/
# 1137          /ˈkɒntrəri/        /ˈkɑːntreri/
# 1428           /dɪˈpraɪv/          /dɪˈpraɪv/
# 1431            /dɪˈraɪv/           /dɪˈraɪv/
# 1473            /dɪˈvəʊt/           /dɪˈvəʊt/
# 1717                /eɪt/               /eɪt/
# 1718           /ˌeɪˈtiːn/          /ˌeɪˈtiːn/
# 1719              /ˈeɪti/             /ˈeɪti/
# 2086     /ˈfɪlm meɪkə(r)/      /ˈfɪlm meɪkər/
# 2203             /ˈfɔːti/           /ˈfɔːrti/
# 2212             /fɔː(r)/              /fɔːr/
# 2213          /ˌfɔːˈtiːn/        /ˌfɔːrˈtiːn/
# 2332   /ˌɡləʊbəlaɪˈzeɪʃn/   /ˌɡləʊbələˈzeɪʃn/
# 2383         /ˈɡriːnhaʊs/        /ˈɡriːnhaʊs/
# 2600        /ˈhaɪdrədʒən/       /ˈhaɪdrədʒən/
# 2717  /ˈɪnfrəstrʌktʃə(r)/   /ˈɪnfrəstrʌktʃər/
# 2976               /liːd/              /liːd/
# 3214             /ˈmɑːʃl/           /ˈmɑːrʃl/
# 3499         /ˌnaɪnˈtiːn/        /ˌnaɪnˈtiːn/
# 3739                /pæn/               /pæn/
# 3811             /ˈpenʃn/            /ˈpenʃn/
# 4081           /ˈprəʊses/          /ˈprɑːses/
# 4365             /rɪˈlaɪ/            /rɪˈlaɪ/
# 4536                /rəʊ/               /rəʊ/
# 4570               /seɪk/              /seɪk/
# 4699         /ˌsevnˈtiːn/        /ˌsevnˈtiːn/
# 4700            /ˈsevnti/           /ˈsevnti/
# 4816         /ˌsɪksˈtiːn/        /ˌsɪksˈtiːn/
# 4817            /ˈsɪksti/           /ˈsɪksti/
# 5152                /sʌm/               /sʌm/
# 5315              /tekst/             /tekst/
# 5358          /ˌθɜːˈtiːn/        /ˌθɜːrˈtiːn/
# 5359             /ˈθɜːti/           /ˈθɜːrti/
# 5362                /ðɪs/               /ðɪs/
# 5519           /ˈtrɪljən/          /ˈtrɪljən/
# 5552            /ˈtwenti/           /ˈtwenti/
# 5625              /əˈpɒn/            /əˈpɑːn/
# 5851               /wɪnd/              /wɪnd/
# 5921                /jeə/               /jeə/

# %%
import json

# Import tusharlock10 dictionary
tusharlock10_dictionary = {}
for symbol in string.ascii_uppercase:
    filename = Path('./tusharlock10-Dictionary') / Path('D' + symbol + '.json')
    with open(filename, mode='r') as f:
        dictionary = json.load(f)
        tusharlock10_dictionary = {**tusharlock10_dictionary, **dictionary}

# %%
# Get relevant fields for some words and put it in a dataframe
def tusharlock10_meaning(w,type):
    try:
        data = tusharlock10_dictionary[w.upper()]
        first_meaning = list(data['MEANINGS'].values())[0]
        meaning_type = first_meaning[0]
        if meaning_type.upper() == type.upper():
            meaning_data = first_meaning[1]
        else:
            meaning_data = ""
    except (KeyError, IndexError, AttributeError):
        meaning_data = ""
    return meaning_data

for idx, row in df_concat.iterrows():
    if row.definition != "":
        continue
    df_concat.loc["definition"] = tusharlock10_meaning(row.word, row.type)

# %%
# Save data to pkl file
df_concat.to_pickle("./data/df_concat.pkl")
# df_concat = pd.read_pickle("./data/df_concat.pkl")

# %% [markdown]
# ## Prepare df_concat for JSON output

# %%
df_concat.head()
# Out:
#       word                definition_link                type cefr  \
# 0        a        /definition/english/a_1  indefinite article   a1
# 1  abandon  /definition/english/abandon_1                verb   b2
# 2  ability  /definition/english/ability_1                noun   a2
# 3     able     /definition/english/able_1           adjective   a2
# 4  abolish    /definition/english/abolish                verb   c1
#
#                                                   UK  \
# 0     /media/english/uk_pron/a/a__/a__gb/a__gb_2.mp3
# 1  /media/english/uk_pron/a/aba/aband/abandon__gb...
# 2  /media/english/uk_pron/a/abi/abili/ability__gb...
# 3  /media/english/uk_pron/a/abl/able_/able__gb_1.mp3
# 4  /media/english/uk_pron/a/abo/aboli/abolish__gb...
#
#                                                   US     word     phon_br  \
# 0  /media/english/us_pron/a/a__/a__us/a__us_2_rr.mp3        a         /ə/
# 1  /media/english/us_pron/a/aba/aband/abandon__us...  abandon  /əˈbændən/
# 2  /media/english/us_pron/a/abi/abili/ability__us...  ability  /əˈbɪləti/
# 3  /media/english/us_pron/a/abl/able_/able__us_2.mp3     able     /ˈeɪbl/
# 4  /media/english/us_pron/a/abo/aboli/abolish__us...  abolish   /əˈbɒlɪʃ/
#
#     phon_n_am                                         definition  \
# 0         /ə/  used before countable or singular nouns referr...
# 1  /əˈbændən/  to leave somebody, especially somebody you are...
# 2  /əˈbɪləti/  the fact that somebody/something is able to do...
# 3     /ˈeɪbl/  to have the skill, intelligence, opportunity, ...
# 4  /əˈbɑːlɪʃ/  to officially end a law, a system or an instit...
#
#                                              example
# 0                                   a man/horse/unit
# 1  abandon somebody, The baby had been abandoned ...
# 2  People with the disease may lose their ability...
# 3     You must be able to speak French for this job.
# 4                      This tax should be abolished.

# %%
# Drop extra work column, definition_link and prep to rename audio links
column_numbers = [x for x in range(df_concat.shape[1])]  # list of columns' integer indices
column_numbers.remove(6) #removing column integer index 0
df_concat = df_concat.iloc[:, column_numbers]
df_concat = df_concat.drop(['definition_link', 'UK', 'US'], axis=1)

# %%
df_concat.head()
# Out:
#       word                type cefr     phon_br   phon_n_am  \
# 0        a  indefinite article   a1         /ə/         /ə/
# 1  abandon                verb   b2  /əˈbændən/  /əˈbændən/
# 2  ability                noun   a2  /əˈbɪləti/  /əˈbɪləti/
# 3     able           adjective   a2     /ˈeɪbl/     /ˈeɪbl/
# 4  abolish                verb   c1   /əˈbɒlɪʃ/  /əˈbɑːlɪʃ/
#
#                                           definition  \
# 0  used before countable or singular nouns referr...
# 1  to leave somebody, especially somebody you are...
# 2  the fact that somebody/something is able to do...
# 3  to have the skill, intelligence, opportunity, ...
# 4  to officially end a law, a system or an instit...
#
#                                              example
# 0                                   a man/horse/unit
# 1  abandon somebody, The baby had been abandoned ...
# 2  People with the disease may lose their ability...
# 3     You must be able to speak French for this job.
# 4                      This tax should be abolished.

# %%
df_concat["uk"] = df_concat.apply(lambda row: f"{row.word}_uk.mp3" , axis=1)
df_concat["us"] = df_concat.apply(lambda row: f"{row.word}_us.mp3" , axis=1)

# %%
df_concat.head()
# Out:
#       word                type cefr     phon_br   phon_n_am  \
# 0        a  indefinite article   a1         /ə/         /ə/
# 1  abandon                verb   b2  /əˈbændən/  /əˈbændən/
# 2  ability                noun   a2  /əˈbɪləti/  /əˈbɪləti/
# 3     able           adjective   a2     /ˈeɪbl/     /ˈeɪbl/
# 4  abolish                verb   c1   /əˈbɒlɪʃ/  /əˈbɑːlɪʃ/
#
#                                           definition  \
# 0  used before countable or singular nouns referr...
# 1  to leave somebody, especially somebody you are...
# 2  the fact that somebody/something is able to do...
# 3  to have the skill, intelligence, opportunity, ...
# 4  to officially end a law, a system or an instit...
#
#                                              example              uk  \
# 0                                   a man/horse/unit        a_uk.mp3
# 1  abandon somebody, The baby had been abandoned ...  abandon_uk.mp3
# 2  People with the disease may lose their ability...  ability_uk.mp3
# 3     You must be able to speak French for this job.     able_uk.mp3
# 4                      This tax should be abolished.  abolish_uk.mp3
#
#                us
# 0        a_us.mp3
# 1  abandon_us.mp3
# 2  ability_us.mp3
# 3     able_us.mp3
# 4  abolish_us.mp3

# %% [markdown]
# ## Oxford 5000

# %%
df_5000 = df_concat
df_5000.to_pickle("./data/oxford_5000.pkl")
# df_5000 = pd.read_pickle("./data/oxford_5000.pkl")
df_5000.to_json('./data/oxford_5000.json', orient='index', index=True, indent=2)
df_5000.to_csv('./data/oxford_5000.csv', index=True)

# %% [markdown]
# ## Oxford 3000

# %%
driver = webdriver.Firefox()
driver.get("https://www.oxfordlearnersdictionaries.com/wordlists/oxford3000-5000")

# %%
# Make sure oxford 3000 is selected
content = driver.page_source
soup = BeautifulSoup(content)
wordlistsContentPanel = soup.find("div", {"id": "wordlistsContentPanel"})
wordlist = wordlistsContentPanel.find("ul")

# %%
# Create empty a frame with columns we wish to extract
columns = ["word", "type", "cefr"]
df = pd.DataFrame(columns=columns)

# Extract fields from wordlist
words = wordlist.findChildren("li", recursive=False)
for word in words:
    if word.has_attr("class"):
        # Skip where class="hidden"
        continue
    a = word.find("a")
    word_name = a.text
    definition_link = a["href"]
    type = word.find("span").text
    div = word.find("div")
    cefr = div.find("span").text
    try:
        uk = div.find("div", {"class": "sound audio_play_button icon-audio pron-uk"})["data-src-mp3"]
        us = div.find("div", {"class": "sound audio_play_button icon-audio pron-us"})["data-src-mp3"]
    except TypeError:
        uk = ""
        us = ""
    # Add data to dataframe
    data = {
        "word": word_name,
        "type": type,
        "cefr": cefr,
    }
    df_new = pd.DataFrame.from_records([data])
    df = pd.concat([df, df_new])

# %%
## Fill in missing oxford 3000 list from oxford 5000
df.head()
# Left join
df_3000=pd.merge(df_5000, df, how='inner', on=['word','type','cefr'])

# %%
df_3000.to_pickle("./data/oxford_3000.pkl")
# df_3000 = pd.read_pickle("./data/oxford_3000.pkl")
df_3000.to_json('./data/oxford_3000.json', orient='index', index=True, indent=2)
df_3000.to_csv('./data/oxford_3000.csv', index=True)

# %% [markdown]
# ## Exclusive 5000

# %%
driver = webdriver.Firefox()
driver.get("https://www.oxfordlearnersdictionaries.com/wordlists/oxford3000-5000")

# %%
# Make sure oxford 5000 exclusive is selected
content = driver.page_source
soup = BeautifulSoup(content)
wordlistsContentPanel = soup.find("div", {"id": "wordlistsContentPanel"})
wordlist = wordlistsContentPanel.find("ul")

# %%
# Create empty a frame with columns we wish to extract
columns = ["word", "type", "cefr"]
df = pd.DataFrame(columns=columns)

# Extract fields from wordlist
words = wordlist.findChildren("li", recursive=False)
for word in words:
    if word.has_attr("class"):
        # Skip where class="hidden"
        continue
    a = word.find("a")
    word_name = a.text
    definition_link = a["href"]
    type = word.find("span").text
    div = word.find("div")
    try:
        cefr = div.find("span").text
    except:
        print(word)
        cefr = ""
    try:
        uk = div.find("div", {"class": "sound audio_play_button icon-audio pron-uk"})["data-src-mp3"]
        us = div.find("div", {"class": "sound audio_play_button icon-audio pron-us"})["data-src-mp3"]
    except TypeError:
        uk = ""
        us = ""
    # Add data to dataframe
    data = {
        "word": word_name,
        "type": type,
        "cefr": cefr,
    }
    df_new = pd.DataFrame.from_records([data])
    df = pd.concat([df, df_new])
# Out:
# <li data-hw="accounting"> <a href="/definition/english/accounting">accounting</a> <span class="pos">noun</span><div> <div class="sound audio_play_button icon-audio pron-uk" data-src-mp3="/media/english/uk_pron/a/acc/accou/accounting__gb_1.mp3" data-src-ogg="/media/english/uk_pron_ogg/a/acc/accou/accounting__gb_1.ogg"> </div> <div class="sound audio_play_button icon-audio pron-us" data-src-mp3="/media/english/us_pron/a/acc/accou/accounting__us_1.mp3" data-src-ogg="/media/english/us_pron_ogg/a/acc/accou/accounting__us_1.ogg"> </div></div></li>
# <li data-hw="angrily"> <a href="/definition/english/angrily">angrily</a> <span class="pos">adverb</span><div> <div class="sound audio_play_button icon-audio pron-uk" data-src-mp3="/media/english/uk_pron/a/ang/angri/angrily__gb_1.mp3" data-src-ogg="/media/english/uk_pron_ogg/a/ang/angri/angrily__gb_1.ogg"> </div> <div class="sound audio_play_button icon-audio pron-us" data-src-mp3="/media/english/us_pron/a/ang/angri/angrily__us_1.mp3" data-src-ogg="/media/english/us_pron_ogg/a/ang/angri/angrily__us_1.ogg"> </div></div></li>
# <li data-hw="cleaning"> <a href="/definition/english/cleaning">cleaning</a> <span class="pos">noun</span><div> <div class="sound audio_play_button icon-audio pron-uk" data-src-mp3="/media/english/uk_pron/c/cle/clean/cleaning__gb_1.mp3" data-src-ogg="/media/english/uk_pron_ogg/c/cle/clean/cleaning__gb_1.ogg"> </div> <div class="sound audio_play_button icon-audio pron-us" data-src-mp3="/media/english/us_pron/c/cle/clean/cleaning__us_1.mp3" data-src-ogg="/media/english/us_pron_ogg/c/cle/clean/cleaning__us_1.ogg"> </div></div></li>
# <li data-hw="feeding"> <a href="/definition/english/feeding">feeding</a> <span class="pos">noun</span><div> <div class="sound audio_play_button icon-audio pron-uk" data-src-mp3="/media/english/uk_pron/f/fee/feedi/feeding__gb_1.mp3" data-src-ogg="/media/english/uk_pron_ogg/f/fee/feedi/feeding__gb_1.ogg"> </div> <div class="sound audio_play_button icon-audio pron-us" data-src-mp3="/media/english/us_pron/f/fee/feedi/feeding__us_1.mp3" data-src-ogg="/media/english/us_pron_ogg/f/fee/feedi/feeding__us_1.ogg"> </div></div></li>
# <li data-hw="major"> <a href="/definition/english/major_2">major</a> <span class="pos">noun</span><div> <div class="sound audio_play_button icon-audio pron-uk" data-src-mp3="/media/english/uk_pron/m/maj/major/major__gb_2.mp3" data-src-ogg="/media/english/uk_pron_ogg/m/maj/major/major__gb_2.ogg"> </div> <div class="sound audio_play_button icon-audio pron-us" data-src-mp3="/media/english/us_pron/m/maj/major/major__us_2.mp3" data-src-ogg="/media/english/us_pron_ogg/m/maj/major/major__us_2.ogg"> </div></div></li>

# %%
## Fill in missing exclusive oxford 5000 list from oxford 5000
df.head()
# Left join
df_5000_exclusive=pd.merge(df_5000, df, how='inner', on=['word','type','cefr'])

# %%
df_5000_exclusive.head()
# Out:
#        word       type cefr    phon_br   phon_n_am  \
# 0   abolish       verb   c1  /əˈbɒlɪʃ/  /əˈbɑːlɪʃ/
# 1  abortion       noun   c1  /əˈbɔːʃn/  /əˈbɔːrʃn/
# 2   absence       noun   c1  /ˈæbsəns/   /ˈæbsəns/
# 3    absent  adjective   c1  /ˈæbsənt/   /ˈæbsənt/
# 4    absorb       verb   b2  /əbˈzɔːb/  /əbˈzɔːrb/
#
#                                           definition  \
# 0  to officially end a law, a system or an instit...
# 1  the deliberate ending of a pregnancy at an ear...
# 2  the fact of somebody being away from a place w...
# 3            not in a place because of illness, etc.
# 4  to take in a liquid, gas or other substance fr...
#
#                                              example               uk  \
# 0                      This tax should be abolished.   abolish_uk.mp3
# 1                         to support/oppose abortion  abortion_uk.mp3
# 2  in somebody's absence, The decision was made i...   absence_uk.mp3
# 3             He was absent from work for two weeks.    absent_uk.mp3
# 4  absorb something, Plants absorb carbon dioxide...    absorb_uk.mp3
#
#                 us
# 0   abolish_us.mp3
# 1  abortion_us.mp3
# 2   absence_us.mp3
# 3    absent_us.mp3
# 4    absorb_us.mp3

# %%
df_5000_exclusive.shape
# Out:
# (2138, 9)

# %%
df_5000_exclusive.to_pickle("./data/oxford_5000_exclusive.pkl")
# df_5000_exclusive = pd.read_pickle("./data/oxford_5000_exclusive.pkl")
df_5000_exclusive.to_json('./data/oxford_5000_exclusive.json', orient='index', index=True, indent=2)
df_5000_exclusive.to_csv('./data/oxford_5000_exclusive.csv', index=True)
